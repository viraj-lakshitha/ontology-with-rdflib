# %%
import rdflib

g = rdflib.Graph()
g.parse('http://dbpedia.org/resource/Berlin')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 import rdflib
#       3 g = rdflib.Graph()
# ----> 4 g.parse('http://dbpedia.org/resource/Berlin')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/rdflib/graph.py:1306, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1223 def parse(
#    1224     self,
#    1225     source: Optional[
#    (...)
#    1233     **args,
#    1234 ):
#    1235     """
#    1236     Parse an RDF source adding the resulting triples to the Graph.
#    1237
#    (...)
#    1303
#    1304     """
# -> 1306     source = create_input_source(
#    1307         source=source,
#    1308         publicID=publicID,
#    1309         location=location,
#    1310         file=file,
#    1311         data=data,
#    1312         format=format,
#    1313     )
# ...

# %%
for s, p, o in g:
    print(s,p,o)
    break

# %%
# Check for the triple exist
from rdflib import URIRef

if (URIRef('http://dbpedia.org/resource/Berlin'), None, None) in g:
    print('Yes')
else:
    print('No')

# %%
# Get set of properties
from rdflib.namespace import RDF, RDFS, OWL, FOAF
from pprint import pprint

# Method 1
property_set_1 = set() # initialize 'set()' to get rid of duplicates
for s, p, o in g:
    property_set_1.add(p)
    
# pprint(property_set_1)

# Method 2
property_set_2 = set()
for p in g.predicates():
    property_set_2.add(p)
    
# pprint(property_set_1)
    
if (len(property_set_1) == len(property_set_2)):
    print('both methods can get same output')

# %%
# Iterate over list of labels
for s, o in g.subject_objects(RDFS.label):
    print(o.value, o.language, o.datatype)

# %%
population = URIRef('http://dbpedia.org/ontology/populationTotal')
for o in g.objects(None, RDFS.label):
    if o.language == "en":
        print(o)
        
for o in g.objects(None, population):
    print(o)

# %%
# Get one value from Graph
from rdflib import Namespace

DBO = Namespace('http://dbpedia.org/ontology/')
DBR = Namespace('http://dbpedia.org/resource/')

print(g.value(DBR['Berlin'], DBO['populationTotal'], None))
